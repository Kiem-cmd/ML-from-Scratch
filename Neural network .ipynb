# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
X_valid, X_train = np.array(X_train_full[:5000]) , np.array(X_train_full[5000:] )
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
m, n = 60000,784
X_train = X_train.reshape(784,55000)/255.0
X_test = X_test.reshape(784,10000)

# %%
def one_hot(Y):
  one_hot_Y = np.zeros((Y.size, Y.max() + 1))
  one_hot_Y[np.arange(Y.size), Y] = 1
  one_hot_Y = one_hot_Y.T
  return one_hot_Y

# %%
def init_params():
    W1 = np.random.rand(10, 784) - 0.4
    b1 = np.random.rand(10, 1) -0.4
    W2 = np.random.rand(10, 10) -0.4
    b2 = np.random.rand(10, 1) -0.4
    return W1, b1, W2, b2
def ReLU(Z):
  return np.maximum(0,Z)
def Softmax(Z):
  return np.exp(Z)/sum(np.exp(Z))
##Softmax = np.vectorize(Softmax)
def forward( W1 , b1 , W2 , b2,X):
  Z1 = np.dot(W1,X) + b1
  A1 = ReLU(Z1)
  Z2 = np.dot(W2,A1) + b2 
  A2 = Softmax(Z2)
  return Z1, A1 , Z2 , A2
def ReLU_deriv(Z):
    return Z > 0
def backward(Z1, A1, Z2, A2, W1, W2, X, Y):
    one_hot_Y = one_hot(Y)
    dZ2 = A2 - one_hot_Y
    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2)
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)
    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1)
    return dW1, db1, dW2, db2
def update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1    
    W2 = W2 - alpha * dW2  
    b2 = b2 - alpha * db2    
    return W1, b1, W2, b2
def get_predictions(A2):
    return np.argmax(A2, axis = 0)

def get_accuracy(predictions, Y):
    return np.sum(predictions == Y) / Y.size
def gradient_descent(X, Y, alpha, iterations):
    W1, b1, W2, b2 = init_params()
    for i in range(iterations):
        Z1, A1, Z2, A2 = forward(W1, b1, W2, b2,X)
        dW1, db1, dW2, db2 = backward(Z1, A1, Z2, A2, W1, W2, X, Y)
        W1, b1, W2, b2 = update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha)
    predictions = get_predictions(A2)
    print(get_accuracy(predictions, Y))
    return W1, b1, W2, b2,predictions

# %%
X_train.shape
# Out:
# (784, 55000)

# %%
y_train.shape
# Out:
# (55000,)

# %%
W1, b1, W2, b2,y_pred = gradient_descent(X_train, y_train, 0.10, 100)
# Out:
# 0.10009090909090909

# %%
y_pred[:10]
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 4, 4, 4])

# %%
y_train[:10]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5], dtype=uint8)

# %%
from keras import models
from keras.layers import Dense

# %%
import tensorflow as tf
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(300,activation ="relu"),
    keras.layers.Dense(100,activation ="relu"),
    keras.layers.Dense(10,activation="softmax")
])

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %%
history = model.fit(X_train,y_train,epochs = 30)
# Out:
# Epoch 1/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.7308 - accuracy: 0.7601
# Epoch 2/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4892 - accuracy: 0.8299
# Epoch 3/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4437 - accuracy: 0.8439
# Epoch 4/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4141 - accuracy: 0.8547
# Epoch 5/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3954 - accuracy: 0.8611
# Epoch 6/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3787 - accuracy: 0.8661
# Epoch 7/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3653 - accuracy: 0.8713
# Epoch 8/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3532 - accuracy: 0.8746
# Epoch 9/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3423 - accuracy: 0.8776
# Epoch 10/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3335 - accuracy: 0.8816
# Epoch 11/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3249 - accuracy: 0.8839
# Epoch 12/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3171 - accuracy: 0.8853
# Epoch 13/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3091 - accuracy: 0.8884
# Epoch 14/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3024 - accuracy: 0.8911
# Epoch 15/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2962 - accuracy: 0.8929
# Epoch 16/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2891 - accuracy: 0.8961
# Epoch 17/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2839 - accuracy: 0.8978
# Epoch 18/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2780 - accuracy: 0.8980
# Epoch 19/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2724 - accuracy: 0.9010
# Epoch 20/30
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2686 - accuracy: 0.9026
# Epoch 21/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2622 - accuracy: 0.9049
# Epoch 22/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2582 - accuracy: 0.9061
# Epoch 23/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2531 - accuracy: 0.9079
# Epoch 24/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2487 - accuracy: 0.9102
# Epoch 25/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2442 - accuracy: 0.9117
# Epoch 26/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2411 - accuracy: 0.9137
# Epoch 27/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2373 - accuracy: 0.9149
# Epoch 28/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2324 - accuracy: 0.9178
# Epoch 29/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2291 - accuracy: 0.9178
# Epoch 30/30
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2241 - accuracy: 0.9190

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.3097 - accuracy: 0.1000
# [2.30972957611084, 0.10000000149011612]
